# %% [markdown]
# # Higher Education Data Visualization
#
# ## Milestone 1: Data Cleaning and Preparation
#
# ### Objective
#
# The objective of this notebook is to demonstrate the data cleaning and preparation process used to integrate multiple higher education datasets into a single analytical dataset.
#
# ### Data Sources
#
# - QS World University Rankings
# - Times Higher Education (THE)
# - OpenAlex
# - World Bank Indicators
#
# The final cleaned dataset produced from this process is used for KPI generation and dashboard development.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Load Source Datasets
#
# The cleaned source datasets generated during the ETL process are loaded for inspection before integration.

# %%
qs = pd.read_csv("../data/university_raw_data/qs_master_clean.csv")

the = pd.read_csv("../data/university_raw_data/the_master.csv")

openalex = pd.read_csv("../data/university_raw_data/openalex_master.csv")

worldbank = pd.read_csv("../data/university_raw_data/worldbank_indicators_raw.csv")

final = pd.read_csv("../data/university_cleaned.csv")

# %% [markdown]
# ## Dataset Overview
#
# The following table shows the number of rows and columns available in each dataset before analysis.

# %%
datasets = {
    "QS Rankings": qs,
    "THE Rankings": the,
    "OpenAlex": openalex,
    "World Bank": worldbank,
    "Final Dataset": final,
}

summary = []

for name, df in datasets.items():

    summary.append(
        {
            "Dataset": name,
            "Rows": df.shape[0],
            "Columns": df.shape[1],
        }
    )

pd.DataFrame(summary)
# Out:
#          Dataset   Rows  Columns
# 0    QS Rankings   7980       15
# 1   THE Rankings  10051       28
# 2       OpenAlex   2865       12
# 3     World Bank   1250       10
# 4  Final Dataset   9969       61

# %% [markdown]
# ## Data Quality Assessment
#
# The datasets were inspected for:
#
# - Missing values
# - Duplicate records
# - Data types
#
# These checks help ensure that the datasets are suitable for integration.

# %%
for name, df in datasets.items():

    print("="*60)
    print(name)

    print("\nShape")
    print(df.shape)

    print("\nMissing Values")
    print(df.isnull().sum().sum())

    print("\nDuplicate Rows")
    print(df.duplicated().sum())

    print("\n")
# Out:
# ...
# QS Rankings
#
# Shape
# (7980, 15)
#
# Missing Values
# 63346
#
# Duplicate Rows
# 0
#
#
# ...
# THE Rankings
#
# Shape
# (10051, 28)
#
# Missing Values
# 18576
#
# Duplicate Rows
# 0
#
#
# ...
# OpenAlex
#
# Shape
# (2865, 12)
#
# Missing Values
# 5312
#
# Duplicate Rows
# 0
#
#
# ...
# World Bank
#
# Shape
# (1250, 10)
#
# Missing Values
# 1955
#
# Duplicate Rows
# 0
#
#
# ...
# Final Dataset
#
# Shape
# (9969, 61)
#
# Missing Values
# 0
#
# Duplicate Rows
# 0

# %% [markdown]
# ## Data Cleaning Performed
#
# The following preprocessing steps were completed before integrating the datasets:
#
# - Removed duplicate records
# - Standardized university names
# - Standardized country names
# - Created a university registry
# - Generated university aliases
# - Matched universities with OpenAlex
# - Applied fuzzy matching for unresolved universities
# - Standardized QS ranking datasets
# - Standardized THE ranking datasets
# - Integrated all datasets into a single analytical dataset

# %% [markdown]
# ## Final Dataset Validation
#
# The integrated dataset is validated before being used for analysis.

# %%
print("Dataset Shape")
print(final.shape)

print("\nDuplicate Rows")
print(final.duplicated().sum())

print("\nDuplicate University-Year Records")
print(
    final.duplicated(
        subset=["university_id","year"]
    ).sum()
)
# Out:
# Dataset Shape
# (9969, 61)
#
# Duplicate Rows
# 0
#
# Duplicate University-Year Records
# 0

# %%
missing = (
    final
    .isnull()
    .sum()
    .sort_values(ascending=False)
)

missing.head(20)
# Out:
# university_id                           0
# normalized_name                         0
# university_name                         0
# country_name                            0
# university                              0
# country_qs                              0
# year                                    0
# qs_rank                                 0
# qs_score                                0
# academic_reputation_score               0
# employer_reputation_score               0
# faculty_student_score                   0
# citations_per_faculty_score             0
# international_faculty_score             0
# international_students_score            0
# international_research_network_score    0
# employment_outcomes_score               0
# sustainability_score                    0
# rank_order                              0
# rank                                    0
# dtype: int64

# %%
final.dtypes
# Out:
# university_id                    str
# normalized_name                  str
# university_name                  str
# country_name                     str
# university                       str
#                               ...
# tertiary_enrollment_ratio    float64
# population                   float64
# literacy_rate_pct            float64
# data_source                      str
# download_timestamp_utc           str
# Length: 61, dtype: object

# %%
final.describe(include="all")
# Out:
#        university_id     normalized_name     university_name   country_name  \
# count           9969                9969                9969           9969
# unique          3565                3565                3565            139
# top          U000001  aalborg university  Aalborg University  United States
# freq               7                   7                   7           1248
# mean             NaN                 NaN                 NaN            NaN
# std              NaN                 NaN                 NaN            NaN
# min              NaN                 NaN                 NaN            NaN
# 25%              NaN                 NaN                 NaN            NaN
# 50%              NaN                 NaN                 NaN            NaN
# 75%              NaN                 NaN                 NaN            NaN
# max              NaN                 NaN                 NaN            NaN
#
# ...

# %% [markdown]
# ## Sample Records
#
# The first five records of the final integrated dataset are shown below.

# %%
final.head()
# Out:
#   university_id     normalized_name     university_name country_name  \
# 0       U000001  aalborg university  Aalborg University      Denmark
# 1       U000001  aalborg university  Aalborg University      Denmark
# 2       U000001  aalborg university  Aalborg University      Denmark
# 3       U000001  aalborg university  Aalborg University      Denmark
# 4       U000001  aalborg university  Aalborg University      Denmark
#
#            university country_qs    year qs_rank qs_score  \
# 0  Aalborg University    Denmark  2017.0     374     31.5
# 1  Aalborg University    Denmark  2018.0     379     32.2
# 2  Aalborg University    Denmark  2019.0     343     31.6
# 3  Aalborg University    Denmark  2020.0     324     33.0
# 4  Aalborg University    Denmark  2021.0     305     34.0
#
#   academic_reputation_score employer_reputation_score faculty_student_score  \
# 0                       5.7                       2.5                 100.0
# ...

# %% [markdown]
# ## Country Distribution
#
# The following output shows the universities available across different countries.

# %%
final["country"].value_counts().head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\python\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 final["country"].value_counts().head(20)
#
# ...

# %% [markdown]
# ## Available Years
#
# The integrated dataset contains university records for multiple years.

# %%
import pandas as pd

df = pd.read_csv("../data/university_cleaned.csv")

print(df.shape)
print(sorted(df["year"].unique()))
print(df["year"].isna().sum())
# Out:
# (7980, 36)
# [2017, 2018, 2019, 2020, 2021, 2022, 2024]
# 0

# %% [markdown]
# ## Final Summary
#
# The Higher Education datasets from QS Rankings, Times Higher Education, OpenAlex, and World Bank were successfully integrated into a single analytical dataset.
#
# The final dataset contains standardized university information, ranking metrics, research indicators, and country-level educational indicators.
#
# This dataset is ready for KPI generation and dashboard development.

# %%
import pandas as pd

qs = pd.read_csv("../data/processed/qs_master_clean.csv")

print(qs["year"].isna().sum())
print(sorted(qs["year"].unique()))
# Out:
# 0
# [2017, 2018, 2019, 2020, 2021, 2022, 2024]
